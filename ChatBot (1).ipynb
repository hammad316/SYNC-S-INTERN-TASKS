# %%
# Out:
# Mounted at /content/drive

# %%
import json
import string
import random 

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file = open('intents.json').read()
data = json.loads(data_file)

data
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi there',
#     'How are you',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day'],
#    'responses': ['Hello, thanks for asking',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How you could help me?',
#     'What you can do?',
#     'What help you provide?',
#     'How you can be helpful?',
#     'What support is offered'],
#    'responses': ['I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies',
#     'Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies'],
#    'context': ['']},
#   {'tag': 'adverse_drug',
#    'patterns': ['How to check Adverse drug reaction?',
#     'Open adverse drugs module',
#     'Give me a list of drugs causing adverse behavior',
#     'List all drugs suitable for patient with adverse reaction',
#     'Which drugs dont have adverse reaction?'],
#    'responses': ['Navigating to Adverse drug reaction module'],
#    'context': ['']},
#   {'tag': 'blood_pressure',
#    'patterns': ['Open blood pressure module',
#     'Task related to blood pressure',
#     'Blood pressure data entry',
#     'I want to log blood pressure results',
#     'Blood pressure data management'],
#    'responses': ['Navigating to Blood Pressure module'],
#    'context': ['']},
#   {'tag': 'blood_pressure_search',
#    'patterns': ['I want to search for blood pressure result history',
#     'Blood pressure for patient',
#     'Load patient blood pressure result',
#     'Show blood pressure results for patient',
#     'Find blood pressure results by ID'],
#    'responses': ['Please provide Patient ID', 'Patient ID?'],
#    'context': ['search_blood_pressure_by_patient_id']},
#   {'tag': 'search_blood_pressure_by_patient_id',
#    'patterns': [],
#    'responses': ['Loading Blood pressure result for Patient'],
#    'context': ['']},
#   {'tag': 'pharmacy_search',
#    'patterns': ['Find me a pharmacy',
#     'Find pharmacy',
#     'List of pharmacies nearby',
#     'Locate pharmacy',
#     'Search pharmacy'],
#    'responses': ['Please provide pharmacy name'],
#    'context': ['search_pharmacy_by_name']},
#   {'tag': 'search_pharmacy_by_name',
#    'patterns': [],
#    'responses': ['Loading pharmacy details'],
#    'context': ['']},
#   {'tag': 'hospital_search',
#    'patterns': ['Lookup for hospital',
#     'Searching for hospital to transfer patient',
#     'I want to search hospital data',
#     'Hospital lookup for patient',
#     'Looking up hospital details'],
#    'responses': ['Please provide hospital name or location'],
#    'context': ['search_hospital_by_params']},
#   {'tag': 'search_hospital_by_params',
#    'patterns': [],
#    'responses': ['Please provide hospital type'],
#    'context': ['search_hospital_by_type']},
#   {'tag': 'search_hospital_by_type',
#    'patterns': [],
#    'responses': ['Loading hospital details'],
#    'context': ['']}]}

# %%
#4 Extracting data_X(features) and data_Y(Target)

words = [] 
classes = [] 
data_X = [] 
data_y = [] 

for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern) 
        words.extend(tokens) 
        data_X.append(pattern) 
        data_y.append(intent["tag"]) ,
  
    if intent["tag"] not in classes:
        classes.append(intent["tag"])


lemmatizer = WordNetLemmatizer()


words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

words = sorted(set(words))
classes = sorted(set(classes))

# %%
training = []
out_empty = [0] * len(classes)

for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
   
   
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx])] = 1

    training.append([bow, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

train_X = np.array(list(training[:, 0]))
train_Y = np.array(list(training[:, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01 )
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=150, verbose=1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               11264
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 14)                910
#
# =================================================================
# Total params: 20,430
# Trainable params: 20,430
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 2/2 [==============================] - 1s 8ms/step - loss: 2.7538 - accuracy: 0.0851
# Epoch 2/150
# 2/2 [==============================] - 0s 10ms/step - loss: 2.4983 - accuracy: 0.1915
# Epoch 3/150
# 2/2 [==============================] - 0s 10ms/step - loss: 2.2946 - accuracy: 0.2340
# Epoch 4/150
# 2/2 [==============================] - 0s 12ms/step - loss: 2.1394 - accuracy: 0.2766
# Epoch 5/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7957 - accuracy: 0.5106
# Epoch 6/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5643 - accuracy: 0.5106
# Epoch 7/150
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2811 - accuracy: 0.6383
# Epoch 8/150
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0478 - accuracy: 0.7872
# Epoch 9/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8026 - accuracy: 0.8723
# Epoch 10/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6755 - accuracy: 0.7872
# Epoch 11/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6138 - accuracy: 0.8085
# Epoch 12/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4666 - accuracy: 0.9149
# Epoch 13/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3863 - accuracy: 0.8723
# Epoch 14/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3002 - accuracy: 0.8936
# Epoch 15/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2794 - accuracy: 0.9362
# Epoch 16/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2286 - accuracy: 0.9362
# Epoch 17/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3102 - accuracy: 0.8936
# Epoch 18/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2473 - accuracy: 0.8936
# Epoch 19/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2109 - accuracy: 0.9362
# Epoch 20/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1556 - accuracy: 0.9362
# Epoch 21/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2880 - accuracy: 0.9149
# Epoch 22/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0903 - accuracy: 1.0000
# Epoch 23/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1430 - accuracy: 0.9574
# Epoch 24/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 25/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 26/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2324 - accuracy: 0.9574
# Epoch 27/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1765 - accuracy: 0.9362
# Epoch 28/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0459 - accuracy: 0.9787
# Epoch 29/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0552 - accuracy: 0.9787
# Epoch 30/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 31/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1121 - accuracy: 0.9574
# Epoch 32/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0709 - accuracy: 0.9787
# Epoch 33/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 34/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0872 - accuracy: 1.0000
# Epoch 35/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0769 - accuracy: 0.9787
# Epoch 36/150
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0878 - accuracy: 0.9787
# Epoch 37/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1175 - accuracy: 0.9574
# Epoch 38/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0728 - accuracy: 0.9574
# Epoch 39/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0591 - accuracy: 0.9787
# Epoch 40/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1362 - accuracy: 0.9574
# Epoch 41/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 42/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 43/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1005 - accuracy: 0.9787
# Epoch 44/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0803 - accuracy: 0.9787
# Epoch 45/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 46/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 47/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 48/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 49/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 50/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 51/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 52/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1061 - accuracy: 0.9574
# Epoch 53/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 54/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0252 - accuracy: 0.9787
# Epoch 55/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 56/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 57/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0715 - accuracy: 0.9574
# Epoch 58/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 59/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 60/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 61/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 62/150
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 63/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 64/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 65/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 66/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 67/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0280 - accuracy: 0.9787
# Epoch 68/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 69/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 70/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0213 - accuracy: 0.9787
# Epoch 71/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 72/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 73/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 74/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 75/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 76/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 77/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 78/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 79/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0326 - accuracy: 0.9787
# Epoch 80/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 81/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 82/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 83/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 84/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 85/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 86/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 87/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 88/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 89/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 90/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 91/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 92/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 93/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 94/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0752 - accuracy: 0.9787
# Epoch 95/150
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0224 - accuracy: 0.9787
# Epoch 96/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 97/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 98/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 99/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 100/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 101/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 102/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 103/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 104/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 105/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 106/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 107/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 108/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 109/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0537 - accuracy: 0.9787
# Epoch 110/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0398 - accuracy: 0.9787
# Epoch 111/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 112/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 113/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 114/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0345 - accuracy: 0.9787
# Epoch 115/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 116/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 117/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 118/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 119/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 120/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 121/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 122/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 123/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 124/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 125/150
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1042 - accuracy: 0.9574
# Epoch 126/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 127/150
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 128/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 129/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 130/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 131/150
# 2/2 [==============================] - 0s 10ms/step - loss: 6.2790e-04 - accuracy: 1.0000
# Epoch 132/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 133/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0268 - accuracy: 0.9787
# Epoch 134/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.9787
# Epoch 135/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 136/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 137/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 138/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 139/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 140/150
# 2/2 [==============================] - 0s 8ms/step - loss: 5.2100e-04 - accuracy: 1.0000
# Epoch 141/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 142/150
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 143/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 144/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 145/150
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5678e-04 - accuracy: 1.0000
# Epoch 146/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 147/150
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 148/150
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 149/150
# 2/2 [==============================] - 0s 8ms/step - loss: 3.1017e-04 - accuracy: 1.0000
# Epoch 150/150
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000

# %%
#7 Preprocessing the Input

def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0] 
  thresh = 0.5
  y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True) 
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]]) 
  return return_list

def get_response(intents_list, intents_json): 
  if len(intents_list) == 0:
    result = "Sorry! I don't understand."
  else:
    tag = intents_list[0]
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
      if i["tag"] == tag:
        result = random.choice(i["responses"])
        break
  return result

# %%
# Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
while True:
    message = input("")
    if message == "0":
      break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# hello
# 1/1 [==============================] - 0s 66ms/step
# Good to see you again
# how are you?
# 1/1 [==============================] - 0s 21ms/step
# Good to see you again
# 0
